# %% [markdown]
# # Identitas
# **Nama**: Imam Hadi Saputra
# **NIM**: 240401010157
# **Kelas**: IF405

# %%
from sklearn.metrics import classification_report, confusion_matrix
# contoh pred dan y_test dari notebook modeling (pastikan dijalankan setelah modeling)
# jika menjalankan terpisah, gunakan contoh berikut:
y_test = [0,1]
pred = [0,1]
print(classification_report(y_test, pred))
print('Confusion matrix:\n', confusion_matrix(y_test, pred))

# %% [markdown]
# ## Kesimpulan
# **Apa yang dipelajari**: ...
# **Temuan utama**: ...
# **Keterbatasan**: ...
