# %% [markdown]
# # Identitas
# **Nama**: Imam Hadi Saputra
# **NIM**: 240401010157
# **Kelas**: IF405

# %%
import pandas as pd
data = {'id':[1,2,3,4],'age':[25,30,22,28],'city':['A','B','A','C']}
df = pd.DataFrame(data)
df.head()

# %%
df.info()
df.describe()

# %% [markdown]
# ## Kesimpulan
# **Apa yang dipelajari**: ...
# **Temuan utama**: ...
# **Keterbatasan**: ...
